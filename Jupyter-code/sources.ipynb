# %%
BOARD_SIZE = 15
board=[]

# %%
def initBoard()  :
    for i in range(BOARD_SIZE):
        row = ["➕"] * BOARD_SIZE
        board.append(row)
        def printBoard():
            for j in range(BOARD_SIZE):
                print(board [i] [j] , end="")
                print ()

# %%
initBoard ()
inputStr = input ("请输入你下棋的坐标，应以x,y的格式：\n")
# Out:
# 请输入你下棋的坐标，应以x,y的格式：
# 2,5

# %%
def printBoard():
    for i in range(BOARD_SIZE):
        for j in range(BOARD_SIZE):
            print(board[i][j], end = "")
        print()

# %%
while inputStr != None :
    x_str, y_str =inputStr.split(sep = ",")
    print("x_str = " + x_str +", y_str = " + y_str)
    board[int(y_str) - 1] [int(x_str) - 1] ="♟"
    printBoard( )
    inputStr =input("请输入你下棋的坐标，应以x,y的格式：\n")
# Out:
# x_str = 2, y_str = 5
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕♟➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# 请输入你下棋的坐标，应以x,y的格式：
# 3,6
# x_str = 3, y_str = 6
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕♟➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕♟➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕
# ➕➕➕➕➕➕➕➕➕➕➕➕➕➕➕

# %%
printBoard ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd2c72fac0b1> in <module>()
#       1
# ----> 2 printBoard ()
#
# NameError: name 'printBoard' is not defined

# %%
import time
import sys

perc = input("请输入每次增长的百分比：")
perc1 = int(perc)
count = 2  
while int(perc)>100 and count > 0:
    perc = input("请重新输入:")
    count = count-1
# Out:
# 请输入每次增长的百分比：12

# %%
if count == 0:
        print("输入字数过多，下次再来试吧！！！")
count = int(100 /perc1)
yushu = (100%perc1)
print("余数是：", yushu)
# Out:
# 余数是： 4

# %%
l1 = "="
l1_perc = l1 + perc + "%"     # =5%
print(l1_perc, end = '\r')
time.sleep(1)
# Out:
# =12%

# %%
for i in range(1, count):  
    h = (i + 1) * perc1               # (1 + 1) * 5, (2 + 1) * 5, (3 + 1) * 5, ...
    l11 = l1 * (i + 1) + str(h) + "%"   # ==10%, ===15%, ====20%
    print(l11, end = '\r')          
    sys.stdout.flush()
    time.sleep(1)
if yushu>0:
    l11 = l1 * (count+1) +"100%" 
    print(l11, end = '\r')
# Out:
# =========100%

# %%
user_name = "Ryan" 
user_age = 9
print("读者名：" ,user_name,"年龄："  ,user_age)
# Out:
# 读者名： Ryan 年龄： 9

# %%
# Out:
# ■■■■■■■■■■■■■■■■■■■■100%

# %%
print("欢迎来到我的世界！！")
print("这个游戏是由小恐龙公司出品！！")
from os import*
from sys import*
from time import*
from random import*
from xes.ext import*
def minecrafts():
    import Minecraft as a
#定义f函数
def f (text):
    stdout.write('\r'+' '*0+'\r')
    stdout.flush()
    for df in text:
        stdout.write(df)
        stdout.flush()
        sleep(0.1)        
print('\033[?25l',end='')
#定义r函数
def r (text):
    random(text)
#定义p函数    
def p (text):
    print(text)
#定义sl函数    
def sl (text):
    sleep(text)
#定义fu函数
def fu (text):
    stdout.write('\r'+' '*0+'\r')
    stdout.flush()
    for df in text:
        stdout.write(df)
        stdout.flush()
        sleep(0.3) 
#定义pm函数        
def pm(text):
    play_mp3(text)
#定义sp函数    
def sp (text):
    speak(text)
#定义fi函数    
def fi (text):
    f(text)
    input()
#定义s函数    
def s ():
    system('clear')
#定义fr函数    
def fr ():
    scale = 59
    for i in range(scale+1):
        aaa = '■'*i
        bbb = '-'*(scale-i)
        ccc =(i/scale)*100
        print("\r\033[1;32m{:^3.0f}%[{}{}]".format(ccc,aaa,bbb),end='')
        sleep(0.1)
def frnn ():
    scale = 9
    for i in range(scale+1):
        aaa = '■'*i
        bbb = '-'*(scale-i)
        ccc =(i/scale)*100
        print("\r\033[1;32m{:^3.0f}%[{}{}]".format(ccc,aaa,bbb),end='')
        sleep(0.1)
f('\n我的世界启动中···')
sleep(0.5)
f('\n加载中···\n')
sleep(0.5)
frnn()
sleep(0.5)
s()
f('资源包加载中···')
sleep(0.5)
f('\n模块设置中···')
sleep(0.5)
f('\n生成地形中···')
sleep(0.5)
s()
f('类型:')
f('\n 1.生存')
f('\n 2.创造')
f('\n创建类型:')
you_1 = input()
if you_1 == '1':
    f('创建世界——\033[31m——\033[32m——')
    f('\n世界名称:')
    name = input()
    sleep(1)
    s()
    f('minecraft1.2.3\n')
    f(name)
    f('\n你出生在一个荒岛,旁边有一个奖励箱，里面有一把锄头,要不要捡？(1.要2.不要)')#调用函数f
    wo2 = input()
    if wo2 == '1':
        f('旁边有一棵树,要不要砍？(1.砍2.不砍)')#调用函数f
        wo3 = input()
        if wo3 == '1':
            f('你挖了很多木头,换了一座工具台,还有剩余的木头,建不建房子？(1.建2.不建)')#调用函数f 
            wo4 = input()
            if wo4 == '1':
                f('你建了一座房子，躲过了僵尸，度过了一个夜晚，成功！')#调用函数f
            if wo4 == '2':
                f('你没有建造房子，僵尸来了')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:100')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:75')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:50')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:25')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:0')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31mgame over')#调用函数f
        if wo3 == '2':
            f('你没木头建造房子，到了晚上，僵尸来了，打不打？(1.打2.不打)')#调用f函数
            wo5 = input()
            if wo5 == '1':
                f('你没有武器打僵尸，死掉了Y(x_x)Y')
            if wo5 == '2':
                f('你被僵尸追上了，死掉了Y(x_x)Y')
    if wo2 == '2':    
        f('你没有锄头挖,挖的不快,挖呀挖,半路遇上僵尸,打不打？(1.打2.不打)')#调用函数f
        wo6 = input()
        if wo6 == '1':
            f('你没有武器打僵尸，死掉了Y(x_x)Y')
        if wo6 == '2':
            f('你被僵尸追上了，死掉了Y(x_x)Y')
elif you_1 == '2':
    f('创建世界——\033[31m——\033[32m——')
    f('\n世界名称:')
    name = input()
    sleep(1)
    s()
    f('minecraft1.2.3\n')
    f(name)
    b = input("\n你在一个森林里要撸树打1，去矿洞探险打2:")
    if b == "1":
        f("你弄了好多木头")
    else:
        f("\n你没武器在矿洞里被僵尸打死了！")
        f("\n游戏结束")
    c = input("\n你造了木装备还有房子，去海里打溺尸按1，去矿洞探险打2:")
    if c == "1":
        f("\n你在海里溺尸打死了")
        f("游戏结束")
    else:
        f("\n你在矿洞里挖了很多矿物！造了套装")
        f("\n制作不易，给个小心心呗！点赞量超过100马上出2版本！")print("欢迎来到我的世界！！")
print("这个游戏是由小恐龙公司出品！！")
from os import*
from sys import*
from time import*
from random import*
from xes.ext import*
def minecrafts():
    import Minecraft as a
#定义f函数
def f (text):
    stdout.write('\r'+' '*0+'\r')
    stdout.flush()
    for df in text:
        stdout.write(df)
        stdout.flush()
        sleep(0.1)        
print('\033[?25l',end='')
#定义r函数
def r (text):
    random(text)
#定义p函数    
def p (text):
    print(text)
#定义sl函数    
def sl (text):
    sleep(text)
#定义fu函数
def fu (text):
    stdout.write('\r'+' '*0+'\r')
    stdout.flush()
    for df in text:
        stdout.write(df)
        stdout.flush()
        sleep(0.3) 
#定义pm函数        
def pm(text):
    play_mp3(text)
#定义sp函数    
def sp (text):
    speak(text)
#定义fi函数    
def fi (text):
    f(text)
    input()
#定义s函数    
def s ():
    system('clear')
#定义fr函数    
def fr ():
    scale = 59
    for i in range(scale+1):
        aaa = '■'*i
        bbb = '-'*(scale-i)
        ccc =(i/scale)*100
        print("\r\033[1;32m{:^3.0f}%[{}{}]".format(ccc,aaa,bbb),end='')
        sleep(0.1)
def frnn ():
    scale = 9
    for i in range(scale+1):
        aaa = '■'*i
        bbb = '-'*(scale-i)
        ccc =(i/scale)*100
        print("\r\033[1;32m{:^3.0f}%[{}{}]".format(ccc,aaa,bbb),end='')
        sleep(0.1)
f('\n我的世界启动中···')
sleep(0.5)
f('\n加载中···\n')
sleep(0.5)
frnn()
sleep(0.5)
s()
f('资源包加载中···')
sleep(0.5)
f('\n模块设置中···')
sleep(0.5)
f('\n生成地形中···')
sleep(0.5)
s()
f('类型:')
f('\n 1.生存')
f('\n 2.创造')
f('\n创建类型:')
you_1 = input()
if you_1 == '1':
    f('创建世界——\033[31m——\033[32m——')
    f('\n世界名称:')
    name = input()
    sleep(1)
    s()
    f('minecraft1.2.3\n')
    f(name)
    f('\n你出生在一个荒岛,旁边有一个奖励箱，里面有一把锄头,要不要捡？(1.要2.不要)')#调用函数f
    wo2 = input()
    if wo2 == '1':
        f('旁边有一棵树,要不要砍？(1.砍2.不砍)')#调用函数f
        wo3 = input()
        if wo3 == '1':
            f('你挖了很多木头,换了一座工具台,还有剩余的木头,建不建房子？(1.建2.不建)')#调用函数f 
            wo4 = input()
            if wo4 == '1':
                f('你建了一座房子，躲过了僵尸，度过了一个夜晚，成功！')#调用函数f
            if wo4 == '2':
                f('你没有建造房子，僵尸来了')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:100')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:75')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:50')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:25')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31m你的血量是:0')#调用函数f
                sl(0.5)#等待0.5秒
                s()#清屏
                f('\033[31mgame over')#调用函数f
        if wo3 == '2':
            f('你没木头建造房子，到了晚上，僵尸来了，打不打？(1.打2.不打)')#调用f函数
            wo5 = input()
            if wo5 == '1':
                f('你没有武器打僵尸，死掉了Y(x_x)Y')
            if wo5 == '2':
                f('你被僵尸追上了，死掉了Y(x_x)Y')
    if wo2 == '2':    
        f('你没有锄头挖,挖的不快,挖呀挖,半路遇上僵尸,打不打？(1.打2.不打)')#调用函数f
        wo6 = input()
        if wo6 == '1':
            f('你没有武器打僵尸，死掉了Y(x_x)Y')
        if wo6 == '2':
            f('你被僵尸追上了，死掉了Y(x_x)Y')
elif you_1 == '2':
    f('创建世界——\033[31m——\033[32m——')
    f('\n世界名称:')
    name = input()
    sleep(1)
    s()
    f('minecraft1.2.3\n')
    f(name)
    b = input("\n你在一个森林里要撸树打1，去矿洞探险打2:")
    if b == "1":
        f("你弄了好多木头")
    else:
        f("\n你没武器在矿洞里被僵尸打死了！")
        f("\n游戏结束")
    c = input("\n你造了木装备还有房子，去海里打溺尸按1，去矿洞探险打2:")
    if c == "1":
        f("\n你在海里溺尸打死了")
        f("游戏结束")
    else:
        f("\n你在矿洞里挖了很多矿物！造了套装")
        f("\n制作不易，给个小心心呗！点赞量超过100马上出2版本！")
# Out:
#   File "<ipython-input-1-bf19c801a126>", line 157
#     f("\n制作不易，给个小心心呗！点赞量超过100马上出2版本！")print("欢迎来到我的世界！！")
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
#  print("欢迎来到香肠派对！！！")
# print("这个游戏是小恐龙公司出品！！")
# print("正在加载中。 。 。")
# import time
# import sys
#
#  perc = input("请输入每次增长的百分比：")
# perc = '5'
# perc1 = int(perc)
# count = 2
# while int(perc)>100 and count > 0:
#     perc = input("请重新输入:")
#     count = count-1
#
#
# if count == 0:
#         print("输入字数过多，下次再来试吧！！！")
# count = int(100 / perc1)
#
# l1 = "■"
# l1_0 = l1 + perc + "%"     # =5%
# print(l1_0, end = '\r')
# time.sleep(1)
# for i in range(1, count):
#     h = (i + 1) * perc1
#     l11 = l1 * (i + 1) + str(h) + "%" # ==10%, ===15%
#     print(l11, end = '\r')
#     sys.stdout.flush()
#     time.sleep(1)
# print("\n加载完成！！！")
#
# from random import *
# number = randint(1000,9999)
# print("验证码是" ,number)
# count = 2
#
# while(count>0):
#
#     answer = input("验证码是：")
#     answer =int(answer)
#     if answer =="number":
#         print("验证通过！！！")
#         print("启动游戏中。。。")
#     else:
#         print("验证未通过!请重新输入:")
#         count = count-1
#
#     if  count == 0 :
#         print("\n输入次数过多，下次再玩吧！！")

# %%
print("欢迎来到香肠派对！！！")
print("这个游戏是小恐龙公司出品！！")
print("正在加载中。 。 。")

import time
import sys

perc = '5' 
perc1 = int(perc)

count = 2  
while int(perc)>100 and count > 0:
    perc = input("请重新输入:")
    count = count-1
if count == 0:
        print("输入字数过多，下次再来试吧！！！")
        
count = int(100 /perc1)
yushu = (100%perc1)
# print("余数是：", yushu)    

l1 = "■"
l1_perc = l1 + perc + "%"     # =5%
print(l1_perc, end = '\r')
time.sleep(1)

for i in range(1, count):  
    h = (i + 1) * perc1               # (1 + 1) * 5, (2 + 1) * 5, (3 + 1) * 5, ...
    l11 = l1 * (i + 1) + str(h) + "%"   #==10%, ===15%, ====20%
    print(l11, end = '\r')          
    sys.stdout.flush()
    time.sleep(1)
if yushu>0:
    l11 = l1 * (count+1) +"100%" 
    print(l11, end = '\r')  
    time.sleep(2)
else:
    time.sleep(1)
    print("\n加载完毕！！")
    
from random import *
number = randint(1000,9999) 
print("\n验证码是" ,number) 
count = 4
while(count>0):
    answer = input("验证码是：")
    answer  = int(    answer  )
    if answer ==number:
        print("验证通过！！！")
        print("启动游戏中。。。")
        print("启动完毕！！！游戏开始！！！")
        print("准备跳伞！！")
        print("\n你想跳到：1.城堡 2.飞行禁地")
        answer = input("请输入你想跳的地方：")
        if answer =="1":
            print("没问题，已跳伞！")
            print("\n城堡有：AK47，三级书包，三级头盔 1.拿 2.不拿")
            answer = input("请输入1或2:")
            if answer =="1":   
                print("恭喜你获得AK47，三级书包，三级头盔！！！")
                print("来了一个有四级头盔的人！ 1.打 2.跑")
                answer = input("请输入1或2:")
                if answer =="1":
                    print("你打死了有四级头盔的人")
                    print("有四级头盔 1.拿 2.不拿")
                    answer = input("请输入1或2:")
                    if answer =="1":
                        print("恭喜你获得四级头盔!!")
                        print("前方有人！1.逃跑 2.打")                        
                        answer = input("请输入1或2:")
                        if answer =="2":
                            print("三杀，大吉大利今晚吃鸡！！！！！")
                        if answer =="1":
                            print("你被打死了，那个人吃鸡了！！！")
                        break    
                    if answer =="2":
                        print("有个叫:狙击战神的拿了，你被打死了！！")
                    break    
                if answer =="2":
                    print("你被打死了！！")
                break    
                
            if answer =="2": 
                print("一个叫：毛绒绒的小狗拿了！把你打死了！！")
            break     
        if answer =="2":
            print("没问题，已跳伞！")
            print("\n飞行禁地有：三级头盔 1.不拿  2.拿")
            answer = input("请输入1或2:")
            if answer =="1":   
                print("那是诱饵，你被一个叫：小虫虫的打死了！") 
            if answer =="2": 
                print("你没被骗！但你没装备被一个叫：胜利属于我们的打死了！")
            break
    else:
        print("验证未通过!请重新输入:")
        count = count-1

    if  count == 0 :
        print("\n输入次数过多，下次再玩吧！！")
# Out:
# 欢迎来到香肠派对！！！
# 这个游戏是小恐龙公司出品！！
# 正在加载中。 。 。
# ■■■■■■■■■■■■■■■■■■■■100%
# 加载完毕！！
#
# 验证码是 1185
# 验证码是：1185
# 验证通过！！！
# 启动游戏中。。。
# 启动完毕！！！游戏开始！！！
# 准备跳伞！！
#
# 你想跳到：1.城堡 2.飞行禁地
# 请输入你想跳的地方：1
# 没问题，已跳伞！
#
# 城堡有：AK47，三级书包，三级头盔 1.拿 2.不拿
# 请输入1或2:1
# 恭喜你获得AK47，三级书包，三级头盔！！！
# 来了一个有四级头盔的人！ 1.打 2.跑
# 请输入1或2:1
# 你打死了有四级头盔的人
# 有四级头盔 1.拿 2.不拿
# 请输入1或2:1
# 恭喜你获得四级头盔!!
# 前方有人！1.逃跑 2.打
# 请输入1或2:1
# 你被打死了，那个人吃鸡了！！！
